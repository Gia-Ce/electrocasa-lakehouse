# %%
# %sql
SHOW TABLES IN electrocasa_sql_catalog.dbo

# %%
# %sql
DESCRIBE TABLE electrocasa_sql_catalog.dbo.trackingenvios

# %%
# %sql
SELECT * FROM electrocasa_sql_catalog.dbo.trackingenvios
